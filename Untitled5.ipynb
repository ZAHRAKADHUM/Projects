# %% [markdown]
# <a href="https://colab.research.google.com/github/ZAHRAKADHUM/Projects/blob/master/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy

# %%
pip install opencv-python

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
file_id='REPLACE_WITH_YOUR_FILE_ID'
downloaded = drive.CreateFile({'id':file_id})
#print('Downloaded content "{}"'.format(downloaded.GetContentString()))

# %%
import cv2
from google.colab.patches import cv2_imshow

image=cv2.imread('/content/drive/MyDrive/Lina2.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=220x220 at 0x7FF4D283B350>

# %%
import cv2
from google.colab.patches import cv2_imshow

image=cv2.imread('/content/drive/MyDrive/Basrah.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=719x733 at 0x7FF4C8928710>

# %%
from PIL import Image
from pylab import*
image=Image.open('/content/drive/MyDrive/Lina2.jpg')
imshow(image)
image1=Image.open('/content/drive/MyDrive/Lina2.jpg').convert('L')
imshow(image1)

# %%
from PIL import Image
from pylab import*
image1=Image.open('/content/drive/MyDrive/Lina2.jpg').convert('L')
image2=Image.open('/content/drive/MyDrive/Basrah.jpg')
c=image2.thumbnail((100,100))
image1.paste(image2,c)
imshow(image1)
