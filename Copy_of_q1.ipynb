# %% [markdown]
# <a href="https://colab.research.google.com/github/ZAHRAKADHUM/Projects/blob/master/Copy_of_q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy

# %%
pip install opencv-python

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
file_id='REPLACE_WITH_YOUR_FILE_ID'
downloaded = drive.CreateFile({'id':file_id})
#print('Downloaded content "{}"'.format(downloaded.GetContentString()))

# %%
import cv2
from google.colab.patches import cv2_imshow
image=cv2.imread('/content/drive/MyDrive/lina.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=717x783 at 0x7FEB934EA290>

# %%
import cv2
from google.colab.patches import cv2_imshow
image=cv2.imread('/content/drive/MyDrive/AB.jpg')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=720x632 at 0x7FEB9139D710>

# %%
pip install PILLOW

# %%
pip install blend
# Out:
# ...
#      |████████████████████████████████| 2.0 MB 5.4 MB/s
# ...
#   Created wheel for blend: filename=Blend-0.1.5-py3-none-any.whl size=1990460 sha256=59f12826207652ae5e3cbe476739278ec22cf97f7b2ece0a814b82570b7ee099
#   Stored in directory: /root/.cache/pip/wheels/d4/ef/13/2e33533efddd03ba337a161e59202f57027b96607e213a2ead
# Successfully built blend
# ...

# %%
from PIL import Image
from pylab import*
image=Image.open('/content/drive/MyDrive/lina.jpg')
imshow(image)
image1=Image.open('/content/drive/MyDrive/lina.jpg').convert('L')
imshow(image1)

# %%
from PIL import Image
from pylab import*
image1=Image.open('/content/drive/MyDrive/lina.jpg').convert('L')
image2=Image.open('/content/drive/MyDrive/AB.jpg')
b=image2.thumbnail((128,128))
image1.paste(image2,b)
imshow(image1)
